# %%
from sklearn.cross_validation import train_test_split
from sklearn.metrics import log_loss
from sklearn import preprocessing
import numpy as np
import pandas as pd
from hyperopt import hp
from hyperopt import fmin, tpe, hp, STATUS_OK, Trials

#import sys
# The path to XGBoost wrappers goes here
#sys.path.append('C:\\Users\\Amine\\Documents\\GitHub\\xgboost\\wrapper')
import xgboost as xgb

# %%
def load_train():
    train = pd.read_csv('./data/train.csv')
    labels = train.target.values
    lbl_enc = preprocessing.LabelEncoder()
    labels = lbl_enc.fit_transform(labels)
    train = train.drop('id', axis=1)
    train = train.drop('target', axis=1)
    return train.values, labels.astype('int32')
def load_test():
    test = pd.read_csv('./data/test.csv')
    test = test.drop('id', axis=1)
    return test.values
def write_submission(preds, output):
    sample = pd.read_csv('./data/sampleSubmission.csv')
    preds = pd.DataFrame(
        preds, index=sample.id.values, columns=sample.columns[1:])
    preds.to_csv(output, index_label='id')
def score(params):
    print "Training with params : "
    print params
    num_round = int(params['n_estimators'])
    del params['n_estimators']
    dtrain = xgb.DMatrix(X_train, label=y_train)
    dvalid = xgb.DMatrix(X_test, label=y_test)
    # watchlist = [(dvalid, 'eval'), (dtrain, 'train')]
    model = xgb.train(params, dtrain, num_round)
    predictions = model.predict(dvalid).reshape((X_test.shape[0], 9))
    score = log_loss(y_test, predictions)
    print "\tScore {0}\n\n".format(score)
    return {'loss': score, 'status': STATUS_OK}
def optimize(trials):
    space = {
             'n_estimators' : hp.quniform('n_estimators', 100, 1000, 1),
             'eta' : hp.quniform('eta', 0.025, 0.5, 0.025),
             'max_depth' : hp.choice('max_depth', np.arange(1, 14, dtype=int)),#hp.quniform('max_depth', 1, 13, 1)
             'min_child_weight' : hp.quniform('min_child_weight', 1, 6, 1),
             'subsample' : hp.quniform('subsample', 0.5, 1, 0.05),
             'gamma' : hp.quniform('gamma', 0.5, 1, 0.05),
             'colsample_bytree' : hp.quniform('colsample_bytree', 0.5, 1, 0.05),
             'num_class' : 9,
             'eval_metric': 'mlogloss',
             'objective': 'multi:softprob',
             'nthread' : 6,
             'silent' : 1
             }
    best = fmin(score, space, algo=tpe.suggest, trials=trials, max_evals=250)
    print best

# %%
X, y = load_train()
print "Splitting data into train and valid ...\n\n"
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, random_state=1234)

#Trials object where the history of search will be stored
trials = Trials()

optimize(trials)
# Out:
# Splitting data into train and valid ...
#
#
# Training with params :
# {'colsample_bytree': 0.9, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 4.0, 'n_estimators': 181.0, 'subsample': 0.9500000000000001, 'eta': 0.17500000000000002, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 3, 'gamma': 0.65}
# 	Score 0.543941078285
#
#
# Training with params :
# {'colsample_bytree': 0.75, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 4.0, 'n_estimators': 284.0, 'subsample': 0.55, 'eta': 0.05, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 8, 'gamma': 0.8500000000000001}
# 	Score 0.478770488525
#
#
# Training with params :
# {'colsample_bytree': 0.9, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 5.0, 'n_estimators': 149.0, 'subsample': 0.9, 'eta': 0.17500000000000002, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 9, 'gamma': 0.8500000000000001}
# 	Score 0.459875862438
#
#
# Training with params :
# {'colsample_bytree': 1.0, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 2.0, 'n_estimators': 675.0, 'subsample': 0.65, 'eta': 0.125, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 9, 'gamma': 0.6000000000000001}
# 	Score 0.46667951828
#
#
# Training with params :
# {'colsample_bytree': 0.9500000000000001, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 1.0, 'n_estimators': 794.0, 'subsample': 0.7000000000000001, 'eta': 0.07500000000000001, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 11, 'gamma': 0.5}
# 	Score 0.460565959359
#
#
# Training with params :
# {'colsample_bytree': 0.55, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 6.0, 'n_estimators': 529.0, 'subsample': 0.7000000000000001, 'eta': 0.42500000000000004, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 4, 'gamma': 0.8500000000000001}
# 	Score 0.482348325322
#
#
# Training with params :
# {'colsample_bytree': 0.9, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 3.0, 'n_estimators': 226.0, 'subsample': 0.6000000000000001, 'eta': 0.17500000000000002, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 13, 'gamma': 0.9}
# 	Score 0.459222091124
#
#
# Training with params :
# {'colsample_bytree': 0.6000000000000001, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 4.0, 'n_estimators': 371.0, 'subsample': 0.5, 'eta': 0.25, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 5, 'gamma': 0.55}
# 	Score 0.475917636089
#
#
# Training with params :
# {'colsample_bytree': 0.8500000000000001, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 4.0, 'n_estimators': 180.0, 'subsample': 0.7000000000000001, 'eta': 0.25, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 12, 'gamma': 0.75}
# 	Score 0.4712791051
#
#
# Training with params :
# {'colsample_bytree': 1.0, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 4.0, 'n_estimators': 973.0, 'subsample': 0.9500000000000001, 'eta': 0.225, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 11, 'gamma': 0.9500000000000001}
# 	Score 0.469402315958
#
#
# Training with params :
# {'colsample_bytree': 0.9, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 2.0, 'n_estimators': 757.0, 'subsample': 0.7000000000000001, 'eta': 0.275, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 5, 'gamma': 0.8}
# 	Score 0.475782221863
#
#
# Training with params :
# {'colsample_bytree': 0.5, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 1.0, 'n_estimators': 387.0, 'subsample': 0.75, 'eta': 0.25, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 10, 'gamma': 0.9}
# 	Score 0.462478161522
#
#
# Training with params :
# {'colsample_bytree': 0.75, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 2.0, 'n_estimators': 195.0, 'subsample': 0.7000000000000001, 'eta': 0.45, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 4, 'gamma': 0.65}
# 	Score 0.483988166292
#
#
# Training with params :
# {'colsample_bytree': 0.55, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 1.0, 'n_estimators': 943.0, 'subsample': 0.6000000000000001, 'eta': 0.125, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 4, 'gamma': 0.8500000000000001}
# 	Score 0.459210058688
#
#
# Training with params :
# {'colsample_bytree': 0.7000000000000001, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 5.0, 'n_estimators': 215.0, 'subsample': 0.9, 'eta': 0.47500000000000003, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 8, 'gamma': 0.9500000000000001}
# 	Score 0.481327759666
#
#
# Training with params :
# {'colsample_bytree': 1.0, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 3.0, 'n_estimators': 637.0, 'subsample': 1.0, 'eta': 0.05, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 1, 'gamma': 0.75}
# 	Score 0.730179063395
#
#
# Training with params :
# {'colsample_bytree': 0.9500000000000001, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 1.0, 'n_estimators': 675.0, 'subsample': 0.9, 'eta': 0.05, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 1, 'gamma': 0.9500000000000001}
# 	Score 0.717032910016
#
#
# Training with params :
# {'colsample_bytree': 0.8500000000000001, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 2.0, 'n_estimators': 644.0, 'subsample': 0.7000000000000001, 'eta': 0.225, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 4, 'gamma': 0.9}
# 	Score 0.463879373273
#
#
# Training with params :
# {'colsample_bytree': 0.8500000000000001, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 2.0, 'n_estimators': 828.0, 'subsample': 0.6000000000000001, 'eta': 0.25, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 10, 'gamma': 0.8500000000000001}
# 	Score 0.492236933433
#
#
# Training with params :
# {'colsample_bytree': 0.65, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 3.0, 'n_estimators': 436.0, 'subsample': 0.8500000000000001, 'eta': 0.125, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 2, 'gamma': 0.65}
# 	Score 0.559273756559
#
#
# Training with params :
# {'colsample_bytree': 0.8, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 3.0, 'n_estimators': 974.0, 'subsample': 0.55, 'eta': 0.35000000000000003, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 13, 'gamma': 1.0}
# 	Score 0.520142257263
#
#
# Training with params :
# {'colsample_bytree': 0.5, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 6.0, 'n_estimators': 886.0, 'subsample': 0.5, 'eta': 0.325, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 13, 'gamma': 0.8}
# 	Score 0.521950060642
#
#
# Training with params :
# {'colsample_bytree': 0.65, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 5.0, 'n_estimators': 518.0, 'subsample': 0.8, 'eta': 0.125, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 7, 'gamma': 1.0}
# 	Score 0.452188612066
#
#
# Training with params :
# {'colsample_bytree': 0.6000000000000001, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 5.0, 'n_estimators': 524.0, 'subsample': 0.8, 'eta': 0.1, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 7, 'gamma': 1.0}
# 	Score 0.45172992279
#
#
# Training with params :
# {'colsample_bytree': 0.65, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 5.0, 'n_estimators': 528.0, 'subsample': 0.8, 'eta': 0.1, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 7, 'gamma': 1.0}
# 	Score 0.45097985328
#
#
# Training with params :
# {'colsample_bytree': 0.65, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 6.0, 'n_estimators': 465.0, 'subsample': 0.8, 'eta': 0.1, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 7, 'gamma': 1.0}
# 	Score 0.453491701475
#
#
# Training with params :
# {'colsample_bytree': 0.6000000000000001, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 5.0, 'n_estimators': 314.0, 'subsample': 0.8, 'eta': 0.025, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 7, 'gamma': 0.9500000000000001}
# 	Score 0.544946456945
#
#
# Training with params :
# {'colsample_bytree': 0.7000000000000001, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 5.0, 'n_estimators': 585.0, 'subsample': 0.8500000000000001, 'eta': 0.17500000000000002, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 6, 'gamma': 1.0}
# 	Score 0.4555408667
#
#
# Training with params :
# {'colsample_bytree': 0.55, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 6.0, 'n_estimators': 578.0, 'subsample': 0.75, 'eta': 0.325, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 3, 'gamma': 0.7000000000000001}
# 	Score 0.481808862261
#
#
# Training with params :
# {'colsample_bytree': 0.6000000000000001, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 5.0, 'n_estimators': 473.0, 'subsample': 0.8500000000000001, 'eta': 0.2, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 7, 'gamma': 0.9}
# 	Score 0.455249517715
#
#
# Training with params :
# {'colsample_bytree': 0.7000000000000001, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 6.0, 'n_estimators': 104.0, 'subsample': 0.9500000000000001, 'eta': 0.025, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 7, 'gamma': 0.8}
# 	Score 0.770548558066
#
#
# Training with params :
# {'colsample_bytree': 0.75, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 4.0, 'n_estimators': 720.0, 'subsample': 0.8, 'eta': 0.07500000000000001, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 7, 'gamma': 0.9500000000000001}
# 	Score 0.448974518508
#
#
# Training with params :
# {'colsample_bytree': 0.8, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 4.0, 'n_estimators': 749.0, 'subsample': 0.75, 'eta': 0.15000000000000002, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 6, 'gamma': 0.7000000000000001}
# 	Score 0.45807127727
#
#
# Training with params :
# {'colsample_bytree': 0.8, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 4.0, 'n_estimators': 887.0, 'subsample': 0.9, 'eta': 0.07500000000000001, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 12, 'gamma': 0.9500000000000001}
# 	Score 0.447070284121
#
#
# Training with params :
# {'colsample_bytree': 0.8, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 4.0, 'n_estimators': 899.0, 'subsample': 1.0, 'eta': 0.07500000000000001, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 12, 'gamma': 0.9500000000000001}
# 	Score 0.45118846464
#
#
# Training with params :
# {'colsample_bytree': 0.75, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 3.0, 'n_estimators': 832.0, 'subsample': 0.9500000000000001, 'eta': 0.375, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 12, 'gamma': 0.9}
# 	Score 0.480992103561
#
#
# Training with params :
# {'colsample_bytree': 0.8, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 4.0, 'n_estimators': 711.0, 'subsample': 0.9, 'eta': 0.05, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 12, 'gamma': 0.8500000000000001}
# 	Score 0.445154832489
#
#
# Training with params :
# {'colsample_bytree': 0.9500000000000001, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 4.0, 'n_estimators': 889.0, 'subsample': 0.9, 'eta': 0.025, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 12, 'gamma': 0.8500000000000001}
# 	Score 0.4496284183
#
#
# Training with params :
# {'colsample_bytree': 0.8500000000000001, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 3.0, 'n_estimators': 804.0, 'subsample': 1.0, 'eta': 0.17500000000000002, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 9, 'gamma': 0.8}
# 	Score 0.457125196336
#
#
# Training with params :
# {'colsample_bytree': 0.8, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 4.0, 'n_estimators': 715.0, 'subsample': 0.9500000000000001, 'eta': 0.15000000000000002, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 12, 'gamma': 0.7000000000000001}
# 	Score 0.459886291275
#
#
# Training with params :
# {'colsample_bytree': 0.9, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 4.0, 'n_estimators': 930.0, 'subsample': 0.8500000000000001, 'eta': 0.4, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 12, 'gamma': 0.55}
# 	Score 0.515455994581
#
#
# Training with params :
# {'colsample_bytree': 0.8, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 3.0, 'n_estimators': 991.0, 'subsample': 0.9, 'eta': 0.30000000000000004, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 2, 'gamma': 0.75}
# 	Score 0.500647080638
#
#
# Training with params :
# {'colsample_bytree': 0.7000000000000001, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 4.0, 'n_estimators': 849.0, 'subsample': 1.0, 'eta': 0.07500000000000001, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 11, 'gamma': 0.8500000000000001}
# 	Score 0.447808390597
#
#
# Training with params :
# {'colsample_bytree': 0.8500000000000001, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 3.0, 'n_estimators': 765.0, 'subsample': 0.65, 'eta': 0.2, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 8, 'gamma': 0.9}
# 	Score 0.469515609134
#
#
# Training with params :
# {'colsample_bytree': 0.9, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 4.0, 'n_estimators': 634.0, 'subsample': 0.9500000000000001, 'eta': 0.5, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 5, 'gamma': 0.6000000000000001}
# 	Score 0.503094596314
#
#
# Training with params :
# {'colsample_bytree': 0.9500000000000001, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 5.0, 'n_estimators': 716.0, 'subsample': 0.9, 'eta': 0.05, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 3, 'gamma': 0.8}
# 	Score 0.534611994773
#
#
# Training with params :
# {'colsample_bytree': 0.75, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 2.0, 'n_estimators': 594.0, 'subsample': 0.8500000000000001, 'eta': 0.15000000000000002, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 12, 'gamma': 0.8500000000000001}
# 	Score 0.455228538618
#
#
# Training with params :
# {'colsample_bytree': 0.9, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 3.0, 'n_estimators': 784.0, 'subsample': 0.65, 'eta': 0.275, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 9, 'gamma': 0.9}
# 	Score 0.494835484848
#
#
# Training with params :
# {'colsample_bytree': 1.0, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 6.0, 'n_estimators': 268.0, 'subsample': 0.9, 'eta': 0.2, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 10, 'gamma': 0.75}
# 	Score 0.460762515429
#
#
# Training with params :
# {'colsample_bytree': 0.8500000000000001, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 4.0, 'n_estimators': 678.0, 'subsample': 0.9500000000000001, 'eta': 0.025, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 12, 'gamma': 0.8}
# 	Score 0.454416295438
#
#
# Training with params :
# {'colsample_bytree': 0.7000000000000001, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 2.0, 'n_estimators': 941.0, 'subsample': 0.75, 'eta': 0.07500000000000001, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 1, 'gamma': 0.9500000000000001}
# 	Score 0.632429512084
#
#
# Training with params :
# {'colsample_bytree': 0.75, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 5.0, 'n_estimators': 859.0, 'subsample': 1.0, 'eta': 0.225, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 11, 'gamma': 0.8500000000000001}
# 	Score 0.458892326646
#
#
# Training with params :
# {'colsample_bytree': 0.8, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 3.0, 'n_estimators': 408.0, 'subsample': 0.8500000000000001, 'eta': 0.05, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 5, 'gamma': 0.5}
# 	Score 0.502757889965
#
#
# Training with params :
# {'colsample_bytree': 0.9500000000000001, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 5.0, 'n_estimators': 812.0, 'subsample': 0.9500000000000001, 'eta': 0.1, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 8, 'gamma': 0.9}
# 	Score 0.451301621966
#
#
# Training with params :
# {'colsample_bytree': 0.9, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 3.0, 'n_estimators': 347.0, 'subsample': 0.55, 'eta': 0.45, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 2, 'gamma': 0.9500000000000001}
# 	Score 0.51734563814
#
#
# Training with params :
# {'colsample_bytree': 0.8500000000000001, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 2.0, 'n_estimators': 629.0, 'subsample': 0.9, 'eta': 0.125, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 13, 'gamma': 0.7000000000000001}
# 	Score 0.459275836068
#
#
# Training with params :
# {'colsample_bytree': 0.8, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 4.0, 'n_estimators': 913.0, 'subsample': 0.65, 'eta': 0.05, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 4, 'gamma': 0.6000000000000001}
# 	Score 0.482892035202
#
#
# Training with params :
# {'colsample_bytree': 0.7000000000000001, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 1.0, 'n_estimators': 998.0, 'subsample': 1.0, 'eta': 0.30000000000000004, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 12, 'gamma': 0.75}
# 	Score 0.470393423249
#
#
# Training with params :
# {'colsample_bytree': 1.0, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 6.0, 'n_estimators': 674.0, 'subsample': 0.75, 'eta': 0.225, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 6, 'gamma': 0.65}
# 	Score 0.473833625665
#
#
# Training with params :
# {'colsample_bytree': 0.65, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 5.0, 'n_estimators': 862.0, 'subsample': 0.7000000000000001, 'eta': 0.15000000000000002, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 3, 'gamma': 0.8500000000000001}
# 	Score 0.480730361642
#
#
# Training with params :
# {'colsample_bytree': 0.75, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 3.0, 'n_estimators': 554.0, 'subsample': 0.8500000000000001, 'eta': 0.125, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 10, 'gamma': 1.0}
# 	Score 0.448568877304
#
#
# Training with params :
# {'colsample_bytree': 0.9, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 4.0, 'n_estimators': 753.0, 'subsample': 0.8, 'eta': 0.1, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 1, 'gamma': 0.8}
# 	Score 0.627718194723
#
#
# Training with params :
# {'colsample_bytree': 0.7000000000000001, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 5.0, 'n_estimators': 472.0, 'subsample': 0.9, 'eta': 0.17500000000000002, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 12, 'gamma': 0.9500000000000001}
# 	Score 0.452938292792
#
#
# Training with params :
# {'colsample_bytree': 0.8500000000000001, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 2.0, 'n_estimators': 604.0, 'subsample': 0.8500000000000001, 'eta': 0.07500000000000001, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 13, 'gamma': 0.9}
# 	Score 0.448222913803
#
#
# Training with params :
# {'colsample_bytree': 0.8, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 6.0, 'n_estimators': 970.0, 'subsample': 0.9500000000000001, 'eta': 0.35000000000000003, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 9, 'gamma': 0.9500000000000001}
# 	Score 0.48131186813
#
#
# Training with params :
# {'colsample_bytree': 0.55, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 4.0, 'n_estimators': 835.0, 'subsample': 1.0, 'eta': 0.05, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 11, 'gamma': 0.8500000000000001}
# 	Score 0.44594595105
#
#
# Training with params :
# {'colsample_bytree': 0.5, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 4.0, 'n_estimators': 960.0, 'subsample': 1.0, 'eta': 0.025, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 11, 'gamma': 0.9}
# 	Score 0.452252603847
#
#
# Training with params :
# {'colsample_bytree': 0.6000000000000001, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 4.0, 'n_estimators': 782.0, 'subsample': 1.0, 'eta': 0.05, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 11, 'gamma': 0.8500000000000001}
# 	Score 0.446411111519
#
#
# Training with params :
# {'colsample_bytree': 0.55, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 4.0, 'n_estimators': 702.0, 'subsample': 1.0, 'eta': 0.1, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 11, 'gamma': 0.8500000000000001}
# 	Score 0.447600914235
#
#
# Training with params :
# {'colsample_bytree': 0.6000000000000001, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 5.0, 'n_estimators': 776.0, 'subsample': 1.0, 'eta': 0.05, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 11, 'gamma': 0.8}
# 	Score 0.446965398312
#
#
# Training with params :
# {'colsample_bytree': 0.55, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 4.0, 'n_estimators': 742.0, 'subsample': 0.9500000000000001, 'eta': 0.025, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 11, 'gamma': 0.75}
# 	Score 0.453594992762
#
#
# Training with params :
# {'colsample_bytree': 0.5, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 3.0, 'n_estimators': 820.0, 'subsample': 0.9500000000000001, 'eta': 0.05, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 11, 'gamma': 0.8}
# 	Score 0.442998385122
#
#
# Training with params :
# {'colsample_bytree': 0.5, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 3.0, 'n_estimators': 671.0, 'subsample': 0.9500000000000001, 'eta': 0.1, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 11, 'gamma': 0.7000000000000001}
# 	Score 0.447717878242
#
#
# Training with params :
# {'colsample_bytree': 0.55, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 1.0, 'n_estimators': 499.0, 'subsample': 0.9500000000000001, 'eta': 0.15000000000000002, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 11, 'gamma': 0.8}
# 	Score 0.45257929173
#
#
# Training with params :
# {'colsample_bytree': 0.5, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 3.0, 'n_estimators': 810.0, 'subsample': 0.9, 'eta': 0.07500000000000001, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 4, 'gamma': 0.65}
# 	Score 0.480079929454
#
#
# Training with params :
# {'colsample_bytree': 0.5, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 2.0, 'n_estimators': 837.0, 'subsample': 0.9, 'eta': 0.17500000000000002, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 8, 'gamma': 0.75}
# 	Score 0.453583836954
#
#
# Training with params :
# {'colsample_bytree': 0.55, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 3.0, 'n_estimators': 562.0, 'subsample': 1.0, 'eta': 0.125, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 2, 'gamma': 0.8}
# 	Score 0.553649692666
#
#
# Training with params :
# {'colsample_bytree': 0.65, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 3.0, 'n_estimators': 735.0, 'subsample': 0.9500000000000001, 'eta': 0.025, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 6, 'gamma': 0.8500000000000001}
# 	Score 0.494856705435
#
#
# Training with params :
# {'colsample_bytree': 0.6000000000000001, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 3.0, 'n_estimators': 922.0, 'subsample': 0.5, 'eta': 0.05, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 5, 'gamma': 0.75}
# 	Score 0.464169411801
#
#
# Training with params :
# {'colsample_bytree': 0.55, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 4.0, 'n_estimators': 611.0, 'subsample': 0.8, 'eta': 0.2, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 11, 'gamma': 0.8}
# 	Score 0.461701196698
#
#
# Training with params :
# {'colsample_bytree': 0.5, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 2.0, 'n_estimators': 651.0, 'subsample': 0.8500000000000001, 'eta': 0.1, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 10, 'gamma': 0.7000000000000001}
# 	Score 0.445393116335
#
#
# Training with params :
# {'colsample_bytree': 0.65, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 1.0, 'n_estimators': 430.0, 'subsample': 0.8500000000000001, 'eta': 0.125, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 10, 'gamma': 0.55}
# 	Score 0.453173065901
#
#
# Training with params :
# {'colsample_bytree': 0.75, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 2.0, 'n_estimators': 536.0, 'subsample': 0.8, 'eta': 0.275, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 10, 'gamma': 0.6000000000000001}
# 	Score 0.489208181161
#
#
# Training with params :
# {'colsample_bytree': 0.5, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 2.0, 'n_estimators': 660.0, 'subsample': 0.8500000000000001, 'eta': 0.07500000000000001, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 10, 'gamma': 0.7000000000000001}
# 	Score 0.443944334588
#
#
# Training with params :
# {'colsample_bytree': 0.6000000000000001, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 2.0, 'n_estimators': 690.0, 'subsample': 0.9, 'eta': 0.25, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 10, 'gamma': 0.65}
# 	Score 0.470323572487
#
#
# Training with params :
# {'colsample_bytree': 0.65, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 1.0, 'n_estimators': 876.0, 'subsample': 0.75, 'eta': 0.07500000000000001, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 10, 'gamma': 0.7000000000000001}
# 	Score 0.448236753234
#
#
# Training with params :
# {'colsample_bytree': 0.5, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 1.0, 'n_estimators': 574.0, 'subsample': 0.7000000000000001, 'eta': 0.15000000000000002, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 3, 'gamma': 0.65}
# 	Score 0.490223262472
#
#
# Training with params :
# {'colsample_bytree': 0.7000000000000001, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 2.0, 'n_estimators': 616.0, 'subsample': 0.8500000000000001, 'eta': 0.125, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 1, 'gamma': 0.6000000000000001}
# 	Score 0.628154118443
#
#
# Training with params :
# {'colsample_bytree': 0.8500000000000001, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 2.0, 'n_estimators': 493.0, 'subsample': 0.8, 'eta': 0.225, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 9, 'gamma': 0.75}
# 	Score 0.470117142229
#
#
# Training with params :
# {'colsample_bytree': 0.55, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 1.0, 'n_estimators': 103.0, 'subsample': 0.9, 'eta': 0.4, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 13, 'gamma': 0.7000000000000001}
# 	Score 0.477160159459
#
#
# Training with params :
# {'colsample_bytree': 0.75, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 3.0, 'n_estimators': 656.0, 'subsample': 0.8500000000000001, 'eta': 0.025, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 4, 'gamma': 0.75}
# 	Score 0.54896783336
#
#
# Training with params :
# {'colsample_bytree': 0.9500000000000001, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 2.0, 'n_estimators': 702.0, 'subsample': 0.7000000000000001, 'eta': 0.30000000000000004, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 5, 'gamma': 0.7000000000000001}
# 	Score 0.48545949768
#
#
# Training with params :
# {'colsample_bytree': 0.6000000000000001, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 3.0, 'n_estimators': 730.0, 'subsample': 0.8, 'eta': 0.17500000000000002, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 2, 'gamma': 0.55}
# 	Score 0.517147297773
#
#
# Training with params :
# {'colsample_bytree': 0.8, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 1.0, 'n_estimators': 451.0, 'subsample': 0.9, 'eta': 0.47500000000000003, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 8, 'gamma': 0.8}
# 	Score 0.501630309132
#
#
# Training with params :
# {'colsample_bytree': 0.7000000000000001, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 2.0, 'n_estimators': 257.0, 'subsample': 0.75, 'eta': 0.07500000000000001, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 6, 'gamma': 0.65}
# 	Score 0.486697169387
#
#
# Training with params :
# {'colsample_bytree': 0.9, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 3.0, 'n_estimators': 355.0, 'subsample': 0.8500000000000001, 'eta': 0.2, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 12, 'gamma': 0.75}
# 	Score 0.465815700439
#
#
# Training with params :
# {'colsample_bytree': 0.5, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 2.0, 'n_estimators': 908.0, 'subsample': 0.9500000000000001, 'eta': 0.025, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 3, 'gamma': 0.9}
# 	Score 0.570684805829
#
#
# Training with params :
# {'colsample_bytree': 0.8, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 3.0, 'n_estimators': 797.0, 'subsample': 0.9, 'eta': 0.1, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 10, 'gamma': 0.5}
# 	Score 0.458591044241
#
#
# Training with params :
# {'colsample_bytree': 0.65, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 3.0, 'n_estimators': 394.0, 'subsample': 0.9500000000000001, 'eta': 0.325, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 1, 'gamma': 0.8500000000000001}
# 	Score 0.598274675919
#
#
# Training with params :
# {'colsample_bytree': 0.75, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 1.0, 'n_estimators': 819.0, 'subsample': 0.8, 'eta': 0.05, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 12, 'gamma': 0.8}
# 	Score 0.446109110964
#
#
# Training with params :
# {'colsample_bytree': 0.8500000000000001, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 2.0, 'n_estimators': 538.0, 'subsample': 0.8500000000000001, 'eta': 0.125, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 9, 'gamma': 0.7000000000000001}
# 	Score 0.453134379213
#
#
# Training with params :
# {'colsample_bytree': 0.6000000000000001, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 3.0, 'n_estimators': 136.0, 'subsample': 0.9, 'eta': 0.07500000000000001, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 13, 'gamma': 0.9}
# 	Score 0.470362377124
#
#
# Training with params :
# {'colsample_bytree': 0.5, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 4.0, 'n_estimators': 497.0, 'subsample': 0.8, 'eta': 0.15000000000000002, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 4, 'gamma': 0.75}
# 	Score 0.475883492866
#
#
# Training with params :
# {'colsample_bytree': 0.7000000000000001, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 2.0, 'n_estimators': 762.0, 'subsample': 0.8500000000000001, 'eta': 0.225, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 10, 'gamma': 0.6000000000000001}
# 	Score 0.47585024607
#
#
# Training with params :
# {'colsample_bytree': 0.9500000000000001, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 5.0, 'n_estimators': 865.0, 'subsample': 0.6000000000000001, 'eta': 0.1, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 7, 'gamma': 0.8}
# 	Score 0.455329106572
#
#
# Training with params :
# {'colsample_bytree': 0.8500000000000001, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 3.0, 'n_estimators': 593.0, 'subsample': 0.9500000000000001, 'eta': 0.05, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 12, 'gamma': 0.65}
# 	Score 0.44559052206
#
#
# Training with params :
# {'colsample_bytree': 0.55, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 4.0, 'n_estimators': 952.0, 'subsample': 0.75, 'eta': 0.25, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 8, 'gamma': 0.55}
# 	Score 0.487225779906
#
#
# Training with params :
# {'colsample_bytree': 0.8, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 1.0, 'n_estimators': 711.0, 'subsample': 0.55, 'eta': 0.025, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 2, 'gamma': 0.9}
# 	Score 0.65097440226
#
#
# Training with params :
# {'colsample_bytree': 0.75, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 3.0, 'n_estimators': 660.0, 'subsample': 0.9500000000000001, 'eta': 0.17500000000000002, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 5, 'gamma': 0.8500000000000001}
# 	Score 0.460102566277
#
#
# Training with params :
# {'colsample_bytree': 0.9, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 2.0, 'n_estimators': 991.0, 'subsample': 0.9, 'eta': 0.375, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 3, 'gamma': 0.7000000000000001}
# 	Score 0.480253128525
#
#
# Training with params :
# {'colsample_bytree': 0.65, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 4.0, 'n_estimators': 628.0, 'subsample': 1.0, 'eta': 0.2, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 6, 'gamma': 0.8}
# 	Score 0.459785080599
#
#
# Training with params :
# {'colsample_bytree': 0.6000000000000001, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 3.0, 'n_estimators': 567.0, 'subsample': 1.0, 'eta': 0.05, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 12, 'gamma': 0.75}
# 	Score 0.446773207094
#
#
# Training with params :
# {'colsample_bytree': 0.5, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 4.0, 'n_estimators': 788.0, 'subsample': 0.9, 'eta': 0.07500000000000001, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 7, 'gamma': 1.0}
# 	Score 0.450304216116
#
#
# Training with params :
# {'colsample_bytree': 0.7000000000000001, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 5.0, 'n_estimators': 687.0, 'subsample': 0.8, 'eta': 0.275, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 1, 'gamma': 0.65}
# 	Score 0.576241868796
#
#
# Training with params :
# {'colsample_bytree': 1.0, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 2.0, 'n_estimators': 850.0, 'subsample': 0.8500000000000001, 'eta': 0.025, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 10, 'gamma': 0.8500000000000001}
# 	Score 0.45204396106
#
#
# Training with params :
# {'colsample_bytree': 0.75, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 1.0, 'n_estimators': 314.0, 'subsample': 0.9500000000000001, 'eta': 0.15000000000000002, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 11, 'gamma': 0.8}
# 	Score 0.453024698638
#
#
# Training with params :
# {'colsample_bytree': 0.55, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 3.0, 'n_estimators': 519.0, 'subsample': 0.7000000000000001, 'eta': 0.1, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 13, 'gamma': 0.9500000000000001}
# 	Score 0.446522836493
#
#
# Training with params :
# {'colsample_bytree': 0.8, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 5.0, 'n_estimators': 894.0, 'subsample': 0.9500000000000001, 'eta': 0.42500000000000004, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 9, 'gamma': 0.7000000000000001}
# 	Score 0.499392049166
#
#
# Training with params :
# {'colsample_bytree': 0.9, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 4.0, 'n_estimators': 732.0, 'subsample': 0.8500000000000001, 'eta': 0.125, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 12, 'gamma': 0.75}
# 	Score 0.459872209296
#
#
# Training with params :
# {'colsample_bytree': 0.65, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 4.0, 'n_estimators': 772.0, 'subsample': 0.75, 'eta': 0.35000000000000003, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 4, 'gamma': 0.8500000000000001}
# 	Score 0.482725519471
#
#
# Training with params :
# {'colsample_bytree': 0.8500000000000001, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 6.0, 'n_estimators': 641.0, 'subsample': 0.65, 'eta': 0.07500000000000001, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 10, 'gamma': 0.9}
# 	Score 0.447595128311
#
#
# Training with params :
# {'colsample_bytree': 0.55, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 2.0, 'n_estimators': 425.0, 'subsample': 1.0, 'eta': 0.025, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 11, 'gamma': 0.8}
# 	Score 0.475313782025
#
#
# Training with params :
# {'colsample_bytree': 0.5, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 3.0, 'n_estimators': 549.0, 'subsample': 0.8, 'eta': 0.15000000000000002, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 8, 'gamma': 0.6000000000000001}
# 	Score 0.453383025826
#
#
# Training with params :
# {'colsample_bytree': 0.7000000000000001, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 1.0, 'n_estimators': 873.0, 'subsample': 0.9, 'eta': 0.17500000000000002, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 2, 'gamma': 0.75}
# 	Score 0.512534065112
#
#
# Training with params :
# {'colsample_bytree': 1.0, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 5.0, 'n_estimators': 802.0, 'subsample': 0.9, 'eta': 0.05, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 5, 'gamma': 0.8500000000000001}
# 	Score 0.474530948291
#
#
# Training with params :
# {'colsample_bytree': 0.9500000000000001, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 3.0, 'n_estimators': 754.0, 'subsample': 0.9500000000000001, 'eta': 0.125, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 6, 'gamma': 0.65}
# 	Score 0.455639988143
#
#
# Training with params :
# {'colsample_bytree': 0.6000000000000001, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 2.0, 'n_estimators': 929.0, 'subsample': 0.8500000000000001, 'eta': 0.1, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 3, 'gamma': 0.9500000000000001}
# 	Score 0.490197878529
#
#
# Training with params :
# {'colsample_bytree': 0.8, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 4.0, 'n_estimators': 454.0, 'subsample': 0.6000000000000001, 'eta': 0.07500000000000001, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 7, 'gamma': 0.7000000000000001}
# 	Score 0.45365558925
#
#
# Training with params :
# {'colsample_bytree': 0.8500000000000001, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 2.0, 'n_estimators': 609.0, 'subsample': 1.0, 'eta': 0.05, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 12, 'gamma': 1.0}
# 	Score 0.454504880568
#
#
# Training with params :
# {'colsample_bytree': 0.5, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 1.0, 'n_estimators': 834.0, 'subsample': 0.8, 'eta': 0.225, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 11, 'gamma': 0.6000000000000001}
# 	Score 0.47406350208
#
#
# Training with params :
# {'colsample_bytree': 0.75, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 3.0, 'n_estimators': 695.0, 'subsample': 0.75, 'eta': 0.2, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 10, 'gamma': 0.8}
# 	Score 0.47196870768
#
#
# Training with params :
# {'colsample_bytree': 0.55, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 4.0, 'n_estimators': 716.0, 'subsample': 0.9, 'eta': 0.1, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 1, 'gamma': 0.8500000000000001}
# 	Score 0.636162233002
#
#
# Training with params :
# {'colsample_bytree': 0.6000000000000001, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 3.0, 'n_estimators': 678.0, 'subsample': 0.8500000000000001, 'eta': 0.025, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 13, 'gamma': 0.7000000000000001}
# 	Score 0.446030172965
#
#
# Training with params :
# {'colsample_bytree': 0.65, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 2.0, 'n_estimators': 587.0, 'subsample': 0.9500000000000001, 'eta': 0.30000000000000004, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 9, 'gamma': 0.75}
# 	Score 0.470548078826
#
#
# Training with params :
# {'colsample_bytree': 0.9, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 4.0, 'n_estimators': 977.0, 'subsample': 0.9, 'eta': 0.125, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 11, 'gamma': 0.8}
# 	Score 0.457095231141
#
#
# Training with params :
# {'colsample_bytree': 0.7000000000000001, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 1.0, 'n_estimators': 661.0, 'subsample': 0.8, 'eta': 0.5, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 4, 'gamma': 0.9}
# 	Score 0.491536116383
#
#
# Training with params :
# {'colsample_bytree': 0.55, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 5.0, 'n_estimators': 480.0, 'subsample': 1.0, 'eta': 0.15000000000000002, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 12, 'gamma': 0.55}
# 	Score 0.449602765938
#
#
# Training with params :
# {'colsample_bytree': 0.8, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 3.0, 'n_estimators': 200.0, 'subsample': 0.8500000000000001, 'eta': 0.17500000000000002, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 10, 'gamma': 0.8500000000000001}
# 	Score 0.453981203247
#
#
# Training with params :
# {'colsample_bytree': 0.5, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 2.0, 'n_estimators': 621.0, 'subsample': 0.7000000000000001, 'eta': 0.05, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 2, 'gamma': 0.9}
# 	Score 0.599291807678
#
#
# Training with params :
# {'colsample_bytree': 0.75, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 6.0, 'n_estimators': 825.0, 'subsample': 0.9500000000000001, 'eta': 0.07500000000000001, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 8, 'gamma': 0.75}
# 	Score 0.450087702669
#
#
# Training with params :
# {'colsample_bytree': 0.8500000000000001, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 3.0, 'n_estimators': 943.0, 'subsample': 0.75, 'eta': 0.125, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 5, 'gamma': 0.65}
# 	Score 0.456955247714
#
#
# Training with params :
# {'colsample_bytree': 0.9500000000000001, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 4.0, 'n_estimators': 741.0, 'subsample': 0.9, 'eta': 0.45, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 6, 'gamma': 0.9500000000000001}
# 	Score 0.485396747521
#
#
# Training with params :
# {'colsample_bytree': 0.6000000000000001, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 2.0, 'n_estimators': 514.0, 'subsample': 1.0, 'eta': 0.25, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 12, 'gamma': 0.7000000000000001}
# 	Score 0.462731648649
#
#
# Training with params :
# {'colsample_bytree': 0.8, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 5.0, 'n_estimators': 368.0, 'subsample': 0.8, 'eta': 0.275, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 11, 'gamma': 0.8}
# 	Score 0.474863724089
#
#
# Training with params :
# {'colsample_bytree': 0.65, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 3.0, 'n_estimators': 847.0, 'subsample': 0.8500000000000001, 'eta': 0.025, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 3, 'gamma': 0.75}
# 	Score 0.571656463258
#
#
# Training with params :
# {'colsample_bytree': 0.5, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 1.0, 'n_estimators': 656.0, 'subsample': 0.8500000000000001, 'eta': 0.1, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 10, 'gamma': 0.7000000000000001}
# 	Score 0.446222530653
#
#
# Training with params :
# {'colsample_bytree': 0.5, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 2.0, 'n_estimators': 766.0, 'subsample': 0.8500000000000001, 'eta': 0.07500000000000001, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 10, 'gamma': 0.65}
# 	Score 0.443203427194
#
#
# Training with params :
# {'colsample_bytree': 0.5, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 2.0, 'n_estimators': 797.0, 'subsample': 0.9, 'eta': 0.05, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 10, 'gamma': 0.65}
# 	Score 0.443619951063
#
#
# Training with params :
# {'colsample_bytree': 0.55, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 1.0, 'n_estimators': 771.0, 'subsample': 0.9, 'eta': 0.05, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 10, 'gamma': 0.6000000000000001}
# 	Score 0.442784560944
#
#
# Training with params :
# {'colsample_bytree': 0.55, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 1.0, 'n_estimators': 915.0, 'subsample': 0.9500000000000001, 'eta': 0.025, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 10, 'gamma': 0.55}
# 	Score 0.448513355579
#
#
# Training with params :
# {'colsample_bytree': 0.5, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 1.0, 'n_estimators': 892.0, 'subsample': 0.9, 'eta': 0.05, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 10, 'gamma': 0.5}
# 	Score 0.444324454561
#
#
# Training with params :
# {'colsample_bytree': 0.55, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 1.0, 'n_estimators': 774.0, 'subsample': 0.9500000000000001, 'eta': 0.1, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 10, 'gamma': 0.6000000000000001}
# 	Score 0.451826745829
#
#
# Training with params :
# {'colsample_bytree': 0.5, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 1.0, 'n_estimators': 807.0, 'subsample': 0.9, 'eta': 0.07500000000000001, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 10, 'gamma': 0.5}
# 	Score 0.448386472255
#
#
# Training with params :
# {'colsample_bytree': 0.55, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 1.0, 'n_estimators': 979.0, 'subsample': 1.0, 'eta': 0.05, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 10, 'gamma': 0.55}
# 	Score 0.446592924531
#
#
# Training with params :
# {'colsample_bytree': 0.5, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 2.0, 'n_estimators': 878.0, 'subsample': 0.9500000000000001, 'eta': 0.025, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 10, 'gamma': 0.6000000000000001}
# 	Score 0.450708779321
#
#
# Training with params :
# {'colsample_bytree': 0.5, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 2.0, 'n_estimators': 788.0, 'subsample': 0.9, 'eta': 0.05, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 10, 'gamma': 0.65}
# 	Score 0.443696328073
#
#
# Training with params :
# {'colsample_bytree': 0.55, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 1.0, 'n_estimators': 854.0, 'subsample': 0.9500000000000001, 'eta': 0.1, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 10, 'gamma': 0.6000000000000001}
# 	Score 0.452104921636
#
#
# Training with params :
# {'colsample_bytree': 0.6000000000000001, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 2.0, 'n_estimators': 998.0, 'subsample': 0.8500000000000001, 'eta': 0.07500000000000001, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 10, 'gamma': 0.55}
# 	Score 0.448538269218
#
#
# Training with params :
# {'colsample_bytree': 0.55, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 1.0, 'n_estimators': 760.0, 'subsample': 1.0, 'eta': 0.025, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 10, 'gamma': 0.5}
# 	Score 0.454752434821
#
#
# Training with params :
# {'colsample_bytree': 0.5, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 2.0, 'n_estimators': 903.0, 'subsample': 0.9, 'eta': 0.15000000000000002, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 7, 'gamma': 0.65}
# 	Score 0.45214500561
#
#
# Training with params :
# {'colsample_bytree': 0.55, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 1.0, 'n_estimators': 728.0, 'subsample': 0.8500000000000001, 'eta': 0.125, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 10, 'gamma': 0.6000000000000001}
# 	Score 0.453818065037
#
#
# Training with params :
# {'colsample_bytree': 0.6000000000000001, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 2.0, 'n_estimators': 807.0, 'subsample': 1.0, 'eta': 0.05, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 1, 'gamma': 0.6000000000000001}
# 	Score 0.700175824085
#
#
# Training with params :
# {'colsample_bytree': 0.5, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 2.0, 'n_estimators': 959.0, 'subsample': 0.9500000000000001, 'eta': 0.07500000000000001, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 9, 'gamma': 0.65}
# 	Score 0.446197839976
#
#
# Training with params :
# {'colsample_bytree': 0.55, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 1.0, 'n_estimators': 922.0, 'subsample': 0.9, 'eta': 0.1, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 11, 'gamma': 0.55}
# 	Score 0.454622858567
#
#
# Training with params :
# {'colsample_bytree': 0.5, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 1.0, 'n_estimators': 819.0, 'subsample': 0.8, 'eta': 0.17500000000000002, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 4, 'gamma': 0.5}
# 	Score 0.461792417097
#
#
# Training with params :
# {'colsample_bytree': 0.6000000000000001, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 2.0, 'n_estimators': 870.0, 'subsample': 0.9, 'eta': 0.025, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 13, 'gamma': 0.65}
# 	Score 0.443033486507
#
#
# Training with params :
# {'colsample_bytree': 0.6000000000000001, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 2.0, 'n_estimators': 940.0, 'subsample': 0.9500000000000001, 'eta': 0.025, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 13, 'gamma': 0.6000000000000001}
# 	Score 0.444131766887
#
#
# Training with params :
# {'colsample_bytree': 0.6000000000000001, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 1.0, 'n_estimators': 868.0, 'subsample': 0.9500000000000001, 'eta': 0.07500000000000001, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 13, 'gamma': 0.55}
# 	Score 0.450307182173
#
#
# Training with params :
# {'colsample_bytree': 0.65, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 2.0, 'n_estimators': 845.0, 'subsample': 0.8500000000000001, 'eta': 0.375, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 13, 'gamma': 0.65}
# 	Score 0.494198972242
#
#
# Training with params :
# {'colsample_bytree': 0.6000000000000001, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 1.0, 'n_estimators': 744.0, 'subsample': 1.0, 'eta': 0.025, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 13, 'gamma': 0.6000000000000001}
# 	Score 0.448487546506
#
#
# Training with params :
# {'colsample_bytree': 0.55, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 2.0, 'n_estimators': 883.0, 'subsample': 0.8, 'eta': 0.1, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 13, 'gamma': 0.55}
# 	Score 0.454918402339
#
#
# Training with params :
# {'colsample_bytree': 0.55, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 3.0, 'n_estimators': 966.0, 'subsample': 0.9, 'eta': 0.125, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 13, 'gamma': 0.7000000000000001}
# 	Score 0.450525840368
#
#
# Training with params :
# {'colsample_bytree': 0.55, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 1.0, 'n_estimators': 697.0, 'subsample': 0.8500000000000001, 'eta': 0.15000000000000002, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 8, 'gamma': 0.65}
# 	Score 0.455208693906
#
#
# Training with params :
# {'colsample_bytree': 0.6000000000000001, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 2.0, 'n_estimators': 827.0, 'subsample': 0.9, 'eta': 0.025, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 5, 'gamma': 0.5}
# 	Score 0.505586372267
#
#
# Training with params :
# {'colsample_bytree': 0.65, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 3.0, 'n_estimators': 767.0, 'subsample': 0.75, 'eta': 0.05, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 2, 'gamma': 0.6000000000000001}
# 	Score 0.581259696659
#
#
# Training with params :
# {'colsample_bytree': 0.5, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 2.0, 'n_estimators': 909.0, 'subsample': 0.8, 'eta': 0.325, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 6, 'gamma': 0.65}
# 	Score 0.489592066552
#
#
# Training with params :
# {'colsample_bytree': 0.6000000000000001, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 3.0, 'n_estimators': 160.0, 'subsample': 0.9500000000000001, 'eta': 0.47500000000000003, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 13, 'gamma': 0.7000000000000001}
# 	Score 0.484923895284
#
#
# Training with params :
# {'colsample_bytree': 0.5, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 1.0, 'n_estimators': 718.0, 'subsample': 0.5, 'eta': 0.07500000000000001, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 11, 'gamma': 0.7000000000000001}
# 	Score 0.447527597723
#
#
# Training with params :
# {'colsample_bytree': 0.55, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 1.0, 'n_estimators': 639.0, 'subsample': 1.0, 'eta': 0.1, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 3, 'gamma': 0.55}
# 	Score 0.511507773361
#
#
# Training with params :
# {'colsample_bytree': 0.55, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 2.0, 'n_estimators': 934.0, 'subsample': 0.8500000000000001, 'eta': 0.4, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 7, 'gamma': 0.6000000000000001}
# 	Score 0.497545604679
#
#
# Training with params :
# {'colsample_bytree': 0.65, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 2.0, 'n_estimators': 863.0, 'subsample': 0.9, 'eta': 0.025, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 13, 'gamma': 0.5}
# 	Score 0.443438548837
#
#
# Training with params :
# {'colsample_bytree': 0.5, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 3.0, 'n_estimators': 992.0, 'subsample': 0.9500000000000001, 'eta': 0.07500000000000001, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 1, 'gamma': 0.65}
# 	Score 0.635202011564
#
#
# Training with params :
# {'colsample_bytree': 0.6000000000000001, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 1.0, 'n_estimators': 788.0, 'subsample': 0.65, 'eta': 0.42500000000000004, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 9, 'gamma': 0.6000000000000001}
# 	Score 0.527865122521
#
#
# Training with params :
# {'colsample_bytree': 0.5, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 2.0, 'n_estimators': 681.0, 'subsample': 1.0, 'eta': 0.17500000000000002, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 11, 'gamma': 0.7000000000000001}
# 	Score 0.453524849319
#
#
# Training with params :
# {'colsample_bytree': 0.55, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 3.0, 'n_estimators': 747.0, 'subsample': 0.8500000000000001, 'eta': 0.125, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 4, 'gamma': 0.65}
# 	Score 0.466495245141
#
#
# Training with params :
# {'colsample_bytree': 0.65, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 2.0, 'n_estimators': 892.0, 'subsample': 0.7000000000000001, 'eta': 0.2, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 8, 'gamma': 0.75}
# 	Score 0.469048457778
#
#
# Training with params :
# {'colsample_bytree': 0.55, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 1.0, 'n_estimators': 840.0, 'subsample': 0.75, 'eta': 0.05, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 2, 'gamma': 0.55}
# 	Score 0.574477604448
#
#
# Training with params :
# {'colsample_bytree': 0.6000000000000001, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 3.0, 'n_estimators': 770.0, 'subsample': 0.55, 'eta': 0.07500000000000001, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 5, 'gamma': 0.65}
# 	Score 0.459204692431
#
#
# Training with params :
# {'colsample_bytree': 0.7000000000000001, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 1.0, 'n_estimators': 593.0, 'subsample': 0.9, 'eta': 0.025, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 11, 'gamma': 0.7000000000000001}
# 	Score 0.45552278897
#
#
# Training with params :
# {'colsample_bytree': 0.5, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 2.0, 'n_estimators': 819.0, 'subsample': 0.8, 'eta': 0.1, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 6, 'gamma': 0.6000000000000001}
# 	Score 0.448996020017
#
#
# Training with params :
# {'colsample_bytree': 0.65, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 1.0, 'n_estimators': 976.0, 'subsample': 0.9500000000000001, 'eta': 0.15000000000000002, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 3, 'gamma': 0.75}
# 	Score 0.484071933436
#
#
# Training with params :
# {'colsample_bytree': 0.55, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 3.0, 'n_estimators': 948.0, 'subsample': 0.8500000000000001, 'eta': 0.05, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 13, 'gamma': 0.55}
# 	Score 0.443705673665
#
#
# Training with params :
# {'colsample_bytree': 0.5, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 2.0, 'n_estimators': 727.0, 'subsample': 0.9, 'eta': 0.025, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 7, 'gamma': 0.7000000000000001}
# 	Score 0.479703929428
#
#
# Training with params :
# {'colsample_bytree': 0.6000000000000001, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 3.0, 'n_estimators': 924.0, 'subsample': 1.0, 'eta': 0.05, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 9, 'gamma': 0.65}
# 	Score 0.448573358533
#
#
# Training with params :
# {'colsample_bytree': 0.5, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 1.0, 'n_estimators': 900.0, 'subsample': 0.9500000000000001, 'eta': 0.125, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 1, 'gamma': 0.6000000000000001}
# 	Score 0.606237884046
#
#
# Training with params :
# {'colsample_bytree': 0.6000000000000001, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 2.0, 'n_estimators': 697.0, 'subsample': 0.8500000000000001, 'eta': 0.2, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 11, 'gamma': 0.65}
# 	Score 0.461775798469
#
#
# Training with params :
# {'colsample_bytree': 0.55, 'silent': 1, 'eval_metric': 'mlogloss', 'nthread': 6, 'min_child_weight': 3.0, 'n_estimators': 563.0, 'subsample': 0.8, 'eta': 0.07500000000000001, 'objective': 'multi:softprob', 'num_class': 9, 'max_depth': 4, 'gamma': 0.75}
